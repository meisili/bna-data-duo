# %%
API_KEY = "yMgwnlBsql8axIBF9rnaf697f5tLlc9S2KYyO2P9"
BASE_URL = "https://commonchemistry.cas.org/api"

def search(query):
    url = f"{BASE_URL}/search"
    headers = {"X-Api-Key": API_KEY}
    params = {"q": query}

    response = requests.get(url, headers=headers, params=params)

    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error {response.status_code}: {response.text}")
        return None

def get_detail(cas_rn):

    url = f"{BASE_URL}/detail"
    headers = {"X-Api-Key": API_KEY}
    params = {"cas_rn": cas_rn}

    response = requests.get(url, headers=headers, params=params)

    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error {response.status.code}: {response.text}")
        return None

if __name__ == "__main__":
    results = search("water")
    print(results)

details = get_detail("7732-18-5")
print(details)
# Out:
# {'count': 1, 'results': [{'rn': '7732-18-5', 'name': 'Water', 'images': ['<svg width="100" viewBox="0 0 100 17" style="fill-opacity:1; color-rendering:auto; color-interpolation:auto; text-rendering:auto; stroke:black; stroke-linecap:square; stroke-miterlimit:10; shape-rendering:auto; stroke-opacity:1; fill:black; stroke-dasharray:none; font-weight:normal; stroke-width:1; font-family:\'Open Sans\'; font-style:normal; stroke-linejoin:miter; font-size:12; stroke-dashoffset:0; image-rendering:auto;" height="17" class="cas-substance-image" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg"><svg class="cas-substance-single-component"><rect y="0" x="0" width="100" stroke="none" ry="7" rx="7" height="17" fill="white" class="cas-substance-group"/><svg y="0" x="37" width="26" viewBox="0 0 26 17" style="fill:black;" height="17" class="cas-substance-single-component-image"><svg><g><g transform="translate(6,8)" style="fill:rgb(230,0,0); text-rendering:geometricPrecision; color-rendering:optimizeQuality; image-rendering:optimizeQuality; font-family:\'Open Sans\'; stroke:rgb(230,0,0); color-interpolation:linearRGB;"><path style="stroke:none;" d="M3.2578 4.1562 L2.2578 4.1562 L2.2578 0.125 L-2.2578 0.125 L-2.2578 4.1562 L-3.2578 4.1562 L-3.2578 -4.4062 L-2.2578 -4.4062 L-2.2578 -0.7656 L2.2578 -0.7656 L2.2578 -4.4062 L3.2578 -4.4062 L3.2578 4.1562 Z"/><path style="stroke:none;" d="M8.0078 5.9656 L4.2578 5.9656 L4.2578 5.4031 L5.7578 3.8875 Q6.4453 3.2 6.6641 2.9031 Q6.8828 2.6062 6.9922 2.325 Q7.1016 2.0437 7.1016 1.7156 Q7.1016 1.2625 6.8281 0.9969 Q6.5547 0.7312 6.0547 0.7312 Q5.7109 0.7312 5.3906 0.8484 Q5.0703 0.9656 4.6797 1.2625 L4.3359 0.825 Q5.1172 0.1687 6.0547 0.1687 Q6.8516 0.1687 7.3125 0.5828 Q7.7734 0.9969 7.7734 1.6844 Q7.7734 2.2312 7.4688 2.7625 Q7.1641 3.2937 6.3203 4.1062 L5.0703 5.325 L5.0703 5.3562 L8.0078 5.3562 L8.0078 5.9656 Z"/><path style="stroke:none;" d="M16.8828 -0.1406 Q16.8828 1.9219 15.8438 3.1016 Q14.8047 4.2812 12.9609 4.2812 Q11.0703 4.2812 10.0391 3.1172 Q9.0078 1.9531 9.0078 -0.1562 Q9.0078 -2.25 10.0391 -3.3984 Q11.0703 -4.5469 12.9609 -4.5469 Q14.8203 -4.5469 15.8516 -3.375 Q16.8828 -2.2031 16.8828 -0.1406 ZM10.0547 -0.1406 Q10.0547 1.5938 10.7969 2.5 Q11.5391 3.4062 12.9609 3.4062 Q14.3828 3.4062 15.1094 2.5078 Q15.8359 1.6094 15.8359 -0.1406 Q15.8359 -1.875 15.1094 -2.7656 Q14.3828 -3.6562 12.9609 -3.6562 Q11.5391 -3.6562 10.7969 -2.7578 Q10.0547 -1.8594 10.0547 -0.1406 Z"/></g></g></svg></svg></svg></svg>']}]}
# {'uri': 'substance/pt/7732185', 'rn': '7732-18-5', 'name': 'Water', 'images': ['<svg width="100" viewBox="0 0 100 17" style="fill-opacity:1; color-rendering:auto; color-interpolation:auto; text-rendering:auto; stroke:black; stroke-linecap:square; stroke-miterlimit:10; shape-rendering:auto; stroke-opacity:1; fill:black; stroke-dasharray:none; font-weight:normal; stroke-width:1; font-family:\'Open Sans\'; font-style:normal; stroke-linejoin:miter; font-size:12; stroke-dashoffset:0; image-rendering:auto;" height="17" class="cas-substance-image" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg"><svg class="cas-substance-single-component"><rect y="0" x="0" width="100" stroke="none" ry="7" rx="7" height="17" fill="white" class="cas-substance-group"/><svg y="0" x="37" width="26" viewBox="0 0 26 17" style="fill:black;" height="17" class="cas-substance-single-component-image"><svg><g><g transform="translate(6,8)" style="fill:rgb(230,0,0); text-rendering:geometricPrecision; color-rendering:optimizeQuality; image-rendering:optimizeQuality; font-family:\'Open Sans\'; stroke:rgb(230,0,0); color-interpolation:linearRGB;"><path style="stroke:none;" d="M3.2578 4.1562 L2.2578 4.1562 L2.2578 0.125 L-2.2578 0.125 L-2.2578 4.1562 L-3.2578 4.1562 L-3.2578 -4.4062 L-2.2578 -4.4062 L-2.2578 -0.7656 L2.2578 -0.7656 L2.2578 -4.4062 L3.2578 -4.4062 L3.2578 4.1562 Z"/><path style="stroke:none;" d="M8.0078 5.9656 L4.2578 5.9656 L4.2578 5.4031 L5.7578 3.8875 Q6.4453 3.2 6.6641 2.9031 Q6.8828 2.6062 6.9922 2.325 Q7.1016 2.0437 7.1016 1.7156 Q7.1016 1.2625 6.8281 0.9969 Q6.5547 0.7312 6.0547 0.7312 Q5.7109 0.7312 5.3906 0.8484 Q5.0703 0.9656 4.6797 1.2625 L4.3359 0.825 Q5.1172 0.1687 6.0547 0.1687 Q6.8516 0.1687 7.3125 0.5828 Q7.7734 0.9969 7.7734 1.6844 Q7.7734 2.2312 7.4688 2.7625 Q7.1641 3.2937 6.3203 4.1062 L5.0703 5.325 L5.0703 5.3562 L8.0078 5.3562 L8.0078 5.9656 Z"/><path style="stroke:none;" d="M16.8828 -0.1406 Q16.8828 1.9219 15.8438 3.1016 Q14.8047 4.2812 12.9609 4.2812 Q11.0703 4.2812 10.0391 3.1172 Q9.0078 1.9531 9.0078 -0.1562 Q9.0078 -2.25 10.0391 -3.3984 Q11.0703 -4.5469 12.9609 -4.5469 Q14.8203 -4.5469 15.8516 -3.375 Q16.8828 -2.2031 16.8828 -0.1406 ZM10.0547 -0.1406 Q10.0547 1.5938 10.7969 2.5 Q11.5391 3.4062 12.9609 3.4062 Q14.3828 3.4062 15.1094 2.5078 Q15.8359 1.6094 15.8359 -0.1406 Q15.8359 -1.875 15.1094 -2.7656 Q14.3828 -3.6562 12.9609 -3.6562 Q11.5391 -3.6562 10.7969 -2.7578 Q10.0547 -1.8594 10.0547 -0.1406 Z"/></g></g></svg></svg></svg></svg>'], 'inchi': 'InChI=1S/H2O/h1H2', 'inchiKey': 'InChIKey=XLYOFNOQVPJJNP-UHFFFAOYSA-N', 'smile': '', 'canonicalSmile': 'O', 'molecularFormula': 'H<sub>2</sub>O', 'molecularMass': '18.02', 'experimentalProperties': [{'name': 'Boiling Point', 'property': '100 °C', 'sourceNumber': 1}, {'name': 'Melting Point', 'property': '0 °C', 'sourceNumber': 0}, {'name': 'Density', 'property': '1.3019 g/cm³', 'sourceNumber': 0}], 'propertyCitations': [{'docUri': 'document/pt/document/56321160', 'sourceNumber': 1, 'source': 'Yusuf, T. A.; Journal of Scientific Research (Rajshahi, Bangladesh), (2019), 11(3), 285-292, CAplus'}], 'synonyms': ['Water', 'R 718', 'Hydrogen oxide (H<sub>2</sub>O)', 'Distilled water', 'NSC 147337', 'Aquafina', 'Ultrex II Ultrapure', 'Milli-Q water', 'Dihydrogen oxide', 'MeSH ID: D014867'], 'replacedRns': ['558440-22-5', '558440-53-2', '652133-48-7', '1202864-49-0', '1371582-34-1', '2886715-16-6'], 'hasMolfile': True}
